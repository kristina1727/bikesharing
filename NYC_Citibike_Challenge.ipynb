# %%
import pandas as pd

# %%
# 1. Create a DataFrame for the 201908-citibike-tripdata data. 
citi_bike_data = pd.read_csv('../201909-citibike-tripdata.csv')
citi_bike_df = pd.DataFrame(citi_bike_data)
citi_bike_df
# Out:
#          tripduration                 starttime                  stoptime  \
# 0                 327  2019-09-01 00:00:01.9580  2019-09-01 00:05:29.3410
# 1                1145  2019-09-01 00:00:04.1430  2019-09-01 00:19:09.8360
# 2                1293  2019-09-01 00:00:07.3090  2019-09-01 00:21:40.7580
# 3                1753  2019-09-01 00:00:08.0640  2019-09-01 00:29:21.5040
# 4                 613  2019-09-01 00:00:12.8510  2019-09-01 00:10:26.1850
# ...               ...                       ...                       ...
# 2444895          1764  2019-09-30 23:59:22.7670  2019-10-01 00:28:47.3180
# 2444896           378  2019-09-30 23:59:27.9270  2019-10-01 00:05:46.5700
# 2444897           561  2019-09-30 23:59:29.1450  2019-10-01 00:08:50.8070
# 2444898           311  2019-09-30 23:59:42.2520  2019-10-01 00:04:54.2320
# 2444899          1500  2019-09-30 23:59:55.3740  2019-10-01 00:24:55.8400
#
#          start station id           start station name  \
# ...

# %%
# 2. Check the datatypes of your columns. 
citi_bike_df.dtypes
# Out:
# tripduration                 int64
# starttime                   object
# stoptime                    object
# start station id             int64
# start station name          object
# start station latitude     float64
# start station longitude    float64
# end station id               int64
# end station name            object
# end station latitude       float64
# end station longitude      float64
# bikeid                       int64
# usertype                    object
# birth year                   int64
# gender                       int64
# dtype: object

# %%
# 3. Convert the 'tripduration' column to datetime datatype.
citi_bike_df['tripduration']= pd.to_datetime(citi_bike_df['tripduration'], unit='s')

# %%
# 4. Check the datatypes of your columns. 
citi_bike_df.dtypes
citi_bike_df.head()
# Out:
#          tripduration                 starttime                  stoptime  \
# 0 1970-01-01 00:05:27  2019-09-01 00:00:01.9580  2019-09-01 00:05:29.3410
# 1 1970-01-01 00:19:05  2019-09-01 00:00:04.1430  2019-09-01 00:19:09.8360
# 2 1970-01-01 00:21:33  2019-09-01 00:00:07.3090  2019-09-01 00:21:40.7580
# 3 1970-01-01 00:29:13  2019-09-01 00:00:08.0640  2019-09-01 00:29:21.5040
# 4 1970-01-01 00:10:13  2019-09-01 00:00:12.8510  2019-09-01 00:10:26.1850
#
#    start station id           start station name  start station latitude  \
# 0              3733           Avenue C & E 18 St               40.730563
# 1              3329         Degraw St & Smith St               40.682915
# 2              3168  Central Park West & W 85 St               40.784727
# 3              3299           E 98 St & Park Ave               40.788130
# 4               486           Broadway & W 29 St               40.746201
#
#    start station longitude  end station id             end station name  \
# ...

# %%
# 5. Export the Dataframe as a new CSV file without the index.
citi_bike_df.to_csv('citi_bike.csv', index=False)
